# %%
import pandas as pd

# %%
df  = pd.read_csv("Noisy_final.csv",header=[0,1,2],index_col=0)
df = df.drop(columns=['pr_rec_score'],level=2).droplevel(2,axis=1)
df.shape
# Out:
# (32, 32)

# %%
df
# Out:
# imb                                    smote                                \
# clf                                       dt        lr        nb       svm
# activemq-5.8.0.csv                  0.155332  0.258343  0.289277  0.244927
# groovy-1_6_BETA_1.csv               0.261175  0.346277  0.256220  0.367419
# activemq-5.3.0.csv                  0.270580  0.349037  0.335609  0.371766
# wicket-1.3.0-incubating-beta-1.csv  0.199404  0.262541  0.307119  0.286032
# jruby-1.1.csv                       0.300911  0.411440  0.375138  0.413342
# jruby-1.4.0.csv                     0.269405  0.351512  0.454545  0.379163
# lucene-2.3.0.csv                    0.384480  0.471456  0.448279  0.529565
# hbase-0.95.2.csv                    0.117855  0.165580  0.303809  0.180569
# lucene-3.0.0.csv                    0.154000  0.324757  0.287471  0.346213
# camel-2.9.0.csv                     0.132479  0.182011  0.226660  0.183404
# ...

# %%
df.columns = map(lambda x:x[0]+x[1],df.columns)

# %%
df.to_csv("foR.csv")
